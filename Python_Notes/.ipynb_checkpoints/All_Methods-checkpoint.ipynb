# %%
| Method           | String  | List  | Tuple  | Set | Dict |
| ---------------- | ------  | ----  | -----  | --- | ---- |

## Tuple
    
| `len()`          | ✅      | ✅    | ✅     | ✅   | ✅    |

| `count()`        | ✅      | ✅    | ✅     | ❌   | ❌    |

| `index()`        | ✅      | ✅    | ✅     | ❌   | ❌    |


  ##String

| `find()`         | ✅      | ❌    | ❌     | ❌   | ❌    |

| `replace()`      | ✅      | ❌    | ❌     | ❌   | ❌    |

| `split()`        | ✅      | ❌    | ❌     | ❌   | ❌    |

| `join()`         | ✅      | ❌    | ❌     | ❌   | ❌    |


##List

| `append()`       | ❌      | ✅    | ❌     | ❌   | ❌    |

| `extend()`       | ❌      | ✅    | ❌     | ❌   | ❌    |

| `insert()`       | ❌      | ✅    | ❌     | ❌   | ❌    |

| `remove()`       | ❌      | ✅    | ❌     | ✅   | ❌    |

| `pop()`          | ❌      | ✅    | ❌     | ✅   | ✅    |

| `clear()`        | ❌      | ✅    | ❌     | ✅   | ✅    |

| `sort()`         | ❌      | ✅    | ❌     | ❌   | ❌    |

| `reverse()`      | ❌      | ✅    | ❌     | ❌   | ❌    |



Set
    
| `remove()`       | ❌      | ✅    | ❌     | ✅   | ❌    |

| `pop()`          | ❌      | ✅    | ❌     | ✅   | ✅    |

| `clear()`        | ❌      | ✅    | ❌     | ✅   | ✅    |

| `add()`          | ❌      | ❌    | ❌     | ✅   | ❌    |

| `update()`       | ❌      | ❌    | ❌     | ✅   | ✅    |

| `union()`        | ❌      | ❌    | ❌     | ✅   | ❌    |

| `intersection()` | ❌      | ❌    | ❌     | ✅   | ❌    |
    

###Dict

| `keys()`         | ❌      | ❌    | ❌     | ❌   | ✅    |

| `values()`       | ❌      | ❌    | ❌     | ❌   | ✅    |

| `items()`        | ❌      | ❌    | ❌     | ❌   | ✅    |

| `get()`          | ❌      | ❌    | ❌     | ❌   | ✅    |
    
| `pop()`          | ❌      | ✅    | ❌     | ✅   | ✅    |
    
| `clear()`        | ❌      | ✅    | ❌     | ✅   | ✅    |

| `update()`       | ❌      | ❌    | ❌     | ✅   | ✅    |

# %%
List + Set + Dict
-----------------
pop()
clear()
copy()

List + Set
----------
remove()

Set + Dict
----------
update()

All Collections
---------------
len()
in
not in
for loop
