# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 10;
y =  20;
z = x+y;
print("Addition of - z is ", z)
type(z)
# Out:
# Addition of - z is  30
# int

# %%
x = 10;
y = 20.9;
z = x < y;
print('REsult: ' , z);
# Out:
# REsult:  True

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
x = "456.22"
type(x)
# Out:
# str

# %%
x = 'Welcome'
print(x[3:5])
# Out:
# co

# %%
x = '''AKSHAY ANCHAN POOJARY'''
# y= x[4:6]
# print(y);
# print(z);
# y=x[11:13]
# print(y);
z=len(x);
x
z
x[2:10:2]
# Out:
# 'SA N'

# %%
x = "PYTHON"
print(x[1:4])
# Out:
# YTH

# %%
x = "AKSHAY"
print(x[:-5:-1])
# Out:
# YAHS

# %%
x = "PYTHON"
print(x[0])
# Out:
# P

# %%
x = "PYTHON"
print(x[-1])
# Out:
# N

# %%
x = "PYTHON"
print(x[1:4])
# Out:
# YTH

# %%
x = "PYTHON"
print(x[:3])
# Out:
# PYT

# %%
x = "MICRODEGREE"

# %%
print(x[2:8])
# Out:
# CRODEG

# %%
print(x[-5:-1])
# Out:
# EGRE

# %%
print(x[::-1])
# Out:
# EERGEDORCIM

# %%
print(x[::2])
# Out:
# MCOERE

# %%
print(x[5:1:-1])
# Out:
# DORC

# %%
x = "My Akshay Name is Akshay Anchan Anchan"
print("Upper : ", x.upper())
print("Lower : ", x.lower())
print("Title Case : ", x.title())
print("Swap Case : ", x.swapcase())
#search
print("Find  : ", x.find("Akshay"))
print("RFind  : ", x.rfind("Akshay"))
print("INDEX  : ", x.index("Akshay"))
print("cOUNT  : ", x.count("Anchan"))
print("Startswicth : " , x.startswith("my"))
print("Endsswicth : " , x.endswith("Anchan"))
# Out:
# Upper :  MY AKSHAY NAME IS AKSHAY ANCHAN ANCHAN
# Lower :  my akshay name is akshay anchan anchan
# Title Case :  My Akshay Name Is Akshay Anchan Anchan
# Swap Case :  mY aKSHAY nAME IS aKSHAY aNCHAN aNCHAN
# Find  :  3
# RFind  :  18
# INDEX  :  3
# cOUNT  :  2
# Startswicth :  False
# Endsswicth :  True

# %%
#validation
price = "12 3"
print(price.isspace())
# Out:
# False
